# %%
import sklearn
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import proteinmlutils.featurizer as protfeat

# %%
protein_df=pd.read_csv("../data/A0A2Z5U3Z0_9INFA_Doud_2016.csv").sample(n=5000, random_state=42)
protein_df.rename(columns={"mutated_sequence": "protein_sequence"}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 protein_df=pd.read_csv("../data/A0A2Z5U3Z0_9INFA_Doud_2016.csv").sample(n=5000, random_state=42)
#       2 protein_df.rename(columns={"mutated_sequence": "protein_sequence"}, inplace=True)
#
# NameError: name 'pd' is not defined

# %%
#perform PCA clustering on the one-hot encoded array
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_arr)
pca.explained_variance_ratio_
# Out:
# array([0.00172073, 0.00152387])

# %%
y_discretize_arr
# Out:
# array([0, 0, 0, ..., 0, 0, 1], shape=(5000,))

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_discretize_arr, cmap='viridis', alpha=0.5)
plt.colorbar(label='DMS Score Discretized')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA of One-Hot Encoded Protein Sequences')
plt.show()
